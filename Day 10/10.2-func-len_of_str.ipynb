# %%
def len_of_str(text):
    count = 0
    for i in text:
        count += 1
    return count

string = input()
result = len_of_str(string)
print(result)
# Out:
#  prem sai
# 8

# %%
def sum(a, b, c, d):
    total = a+b+c+d
    return total

a = int(input())
b = int(input())
c = int(input())
d = int(input())
result = sum(a,b,c,d)
print(result)
# Out:
#  1
#  2
#  3
#  4
# 10
