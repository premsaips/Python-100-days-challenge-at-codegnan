# %%
#Default arguements

def add(a, b, c = 0, d = 0):
    return a + b + c + d
print(add(1,2,3,4))
print(add(1,3,4))
print(add(1,2))
# Out:
# 10
# 8
# 3

# %%
#Default arguements

def add(a, b, c = 1, d = 1):
    return a * b * c * d
print(add(1,2,3,4))
print(add(1,3,4))
print(add(1,2))
# Out:
# 24
# 12
# 2
