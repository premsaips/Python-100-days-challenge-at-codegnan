# %%
#List operations
'''
---->1. concatenation
---->2. repeate
'''

# %%
#List concatenation
l1 = [1, 2, 3]
l2 = [3, 2, 1]
l3 = l1 + l2
print(l3)
# Out:
# [1, 2, 3, 3, 2, 1]

# %%
#Add 100 to end of the list
lst = [1,2,3]
print(lst + [100])
# Out:
# [1, 2, 3, 2, 3, 4, 6, 5, 100]

# %%
#Empty list representation
lst1 = []
lst2 = list()
print(type(lst2))
print(len(lst1),len(lst2))
# Out:
# <class 'list'>
# 0 0
