# %%
#Variable length of positional arguments
def add(a, *args):
    
add(1,2,3,4,5,6,7,8,9)
# Out:
# 1
# (2, 3, 4, 5, 6, 7, 8, 9)

# %%
#Variable length of positional arguments
def add(a, *args):
    s = a
    for num in args:
        s += num
    return s
print(add(1,2,3,4,5))
# Out:
# 15
